# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import matplotlib
matplotlib.rcParams['font.family']='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus']=False

# %%
crimeDF =pd.read_csv('../data/crime_in_Seoul.csv',encoding='euc-kr',thousands=',')
crimeDF
# Out:
#      관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거
# 0    중부서      2      2      3      2    105     65   1395    477   1355   1170
# 1    종로서      3      3      6      5    115     98   1070    413   1278   1070
# 2   남대문서      1      0      6      4     65     46   1153    382    869    794
# 3   서대문서      2      2      5      4    154    124   1812    738   2056   1711
# 4    혜화서      3      2      5      4     96     63   1114    424   1015    861
# 5    용산서      5      5     14     14    194    173   1557    587   2050   1704
# 6    성북서      2      2      2      1     86     71    953    409   1194   1015
# 7   동대문서      5      5     13     13    173    146   1981    814   2548   2227
# 8    마포서      8      8     14     10    294    247   2555    813   2983   2519
# 9   영등포서     14     12     22     20    295    183   2964    978   3572   2961
# 10   성동서      4      4      9      8    126    119   1607    597   1612   1395
# ...

# %% [markdown]
# # 샘플 문제

# %% [markdown]
# ## 1. 살인발생이 가장높은 관서명, 살인발생,살인검거를 출력하시요

# %%
crimeDF['살인 발생'].max()

crimeDF[crimeDF['살인 발생'] == crimeDF['살인 발생'].max()][['관서명','살인 발생','살인 검거']]
# Out:
#     관서명  살인 발생  살인 검거
# 9  영등포서     14     12

# %% [markdown]
# ## 2. 관서별 절도발생,절도검거에 대한 바차트를 그리시요

# %%
crimeDF.plot( kind= 'bar', y=['절도 검거','절도 발생'], rot = 0)
plt.show()

# %% [markdown]
# ## 3. 절도검거율 을 구하고 컬럼을 추가 하시요

# %%
crimeDF['절도 검거율(%)'] = ((crimeDF['절도 검거']/crimeDF['절도 발생'])*100).round(2)
crimeDF
# Out:
#      관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  \
# 0    중부서      2      2      3      2    105     65   1395    477   1355
# 1    종로서      3      3      6      5    115     98   1070    413   1278
# 2   남대문서      1      0      6      4     65     46   1153    382    869
# 3   서대문서      2      2      5      4    154    124   1812    738   2056
# 4    혜화서      3      2      5      4     96     63   1114    424   1015
# 5    용산서      5      5     14     14    194    173   1557    587   2050
# 6    성북서      2      2      2      1     86     71    953    409   1194
# 7   동대문서      5      5     13     13    173    146   1981    814   2548
# 8    마포서      8      8     14     10    294    247   2555    813   2983
# 9   영등포서     14     12     22     20    295    183   2964    978   3572
# 10   성동서      4      4      9      8    126    119   1607    597   1612
# 11   동작서      5      5      9      5    285    139   1865    661   1910
# ...

# %% [markdown]
# # 작성 문제

# %% [markdown]
# ## 1. 절도 발생 빈도가 높은 top 5 를 나타내라

# %%
crimeDF2 =pd.read_csv('data/crime_in_Seoul.csv',encoding='euc-kr',thousands=',', index_col='관서명')
crimeDF2['절도 발생'].nlargest(5)
# Out:
# 관서명
# 송파서     3239
# 광진서     3026
# 영등포서    2964
# 관악서     2706
# 마포서     2555
# Name: 절도 발생, dtype: int64

# %%
crimeDF[['절도 발생','관서명']].sort_values(by='절도 발생', ascending= False)[0:5]
# Out:
#     절도 발생   관서명
# 25   3239   송파서
# 12   3026   광진서
# 9    2964  영등포서
# 18   2706   관악서
# 8    2555   마포서

# %% [markdown]
# # 2. 관서별 살인 발생, 살인 검거에 대한 바차트 그리기

# %%
crimeDF.plot(kind='bar', y=['살인 발생', '살인 검거'], figsize=(10,8))
plt.show()

# %%
#살인 발생 기준 상위 5개 관서명
crimeDF.nlargest(5, '살인 발생')[['살인 발생', '살인 검거']]
# Out:
#     살인 발생  살인 검거
# 9      14     12
# 16     13     12
# 25     11     10
# 26     10     10
# 30     10      7

# %%
# 살인 검거 기준 상위 5개 관서명
crimeDF.nlargest(5, '살인 검거')[['살인 발생', '살인 검거']]
# Out:
#     살인 발생  살인 검거
# 9      14     12
# 16     13     12
# 25     11     10
# 26     10     10
# 8       8      8

# %% [markdown]
# ## bar차트와 nlargest를 이용하여 종합해서 살펴본 결과,
# ## 살인 발생 수가 많은 관서가 살인 검거 수도 높다는 것을 알 수 있음
# ## - 영등포서, 중랑서, 송파서, 노원서

# %% [markdown]
# # 3. 관서별 위험도와 위험도 수준 평가
# ## 기준 - 살인발생, 강도발생, 강간발생의 평균

# %%
crimeDF['위험도'] = round((crimeDF['살인 발생']+crimeDF['강도 발생']+crimeDF['강간 발생'])/3, 2)
print(crimeDF['위험도'].quantile(0.33))
print(crimeDF['위험도'].quantile(0.66))
# Out:
# 42.833
# 71.264

# %%
crimeDF['위험도 수준'] = crimeDF['위험도'].apply(lambda x:'위험도 매우높음' if x>=71 else '위험도 높음' if x>=43 else '보통')
crimeDF[['관서명','위험도','위험도 수준']].sort_values(by ='위험도', ascending= False)
# Out:
#      관서명     위험도    위험도 수준
# 23   서초서  116.33  위험도 매우높음
# 18   관악서  113.67  위험도 매우높음
# 9   영등포서  110.33  위험도 매우높음
# 17   강남서  106.00  위험도 매우높음
# 8    마포서  105.33  위험도 매우높음
# 22   구로서  101.33  위험도 매우높음
# 11   동작서   99.67  위험도 매우높음
# 19   강서서   94.00  위험도 매우높음
# 12   광진서   86.00  위험도 매우높음
# 25   송파서   81.33  위험도 매우높음
# 26   노원서   71.33  위험도 매우높음
# 5    용산서   71.00  위험도 매우높음
# 16   중랑서   70.33    위험도 높음
# 7   동대문서   63.67    위험도 높음
# 14   강북서   58.00    위험도 높음
# 20   강동서   55.33    위험도 높음
# 30   수서서   55.00    위험도 높음
# 3   서대문서   53.67    위험도 높음
# 15   금천서   53.33    위험도 높음
# 10   성동서   46.33    위험도 높음
# 24   양천서   43.00    위험도 높음
# 1    종로서   41.33        보통
# 29   도봉서   38.00        보통
# 0    중부서   36.67        보통
# 4    혜화서   34.67        보통
# 28   은평서   34.67        보통
# 6    성북서   30.00        보통
# 13   서부서   24.67        보통
# 2   남대문서   24.00        보통
# 21   종암서   23.33        보통
# 27   방배서   20.33        보통

# %%
# 상위 5개 위험도 지역
crimeDF[['관서명','위험도','위험도 수준']].sort_values(by ='위험도', ascending= False)[0:5]
# Out:
#      관서명     위험도    위험도 수준
# 23   서초서  116.33  위험도 매우높음
# 18   관악서  113.67  위험도 매우높음
# 9   영등포서  110.33  위험도 매우높음
# 17   강남서  106.00  위험도 매우높음
# 8    마포서  105.33  위험도 매우높음
