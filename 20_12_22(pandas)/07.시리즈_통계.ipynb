# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import matplotlib

# 한글 깨짐 방지
matplotlib.rcParams['font.family']='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
data = {'aa':10,'bb':20,'cc':30,'dd':40,'ee':50}
sr = pd.Series(data, name='국어점수')
sr
# Out:
# aa    10
# bb    20
# cc    30
# dd    40
# ee    50
# Name: 국어점수, dtype: int64

# %%
sr.max()
# Out:
# 50

# %%
# 가장 큰 값의 인덱스 값
sr.idxmax()
# Out:
# 'ee'

# %%
# 45이하인데이터의 가장큰값을 구하시요.
sr[sr<=45].max()
# Out:
# 40

# %%
sr.head(2)
# Out:
# aa    10
# bb    20
# Name: 국어점수, dtype: int64

# %%
sr.tail(2)
# Out:
# dd    40
# ee    50
# Name: 국어점수, dtype: int64

# %%
# 값이 가장 큰거 출력
sr.nlargest(2)
# Out:
# ee    50
# dd    40
# Name: 국어점수, dtype: int64

# %%
sr['cc'] = 40
sr
# Out:
# aa    10
# bb    20
# cc    40
# dd    40
# ee    50
# Name: 국어점수, dtype: int64

# %%
sr.nlargest(2, keep='all')
# Out:
# ee    50
# cc    40
# dd    40
# Name: 국어점수, dtype: int64

# %%
sr.nsmallest(2,keep='last')
# Out:
# aa    10
# bb    20
# Name: 국어점수, dtype: int64

# %%
sr.sum()
# Out:
# 160

# %%
sr.mean()
# Out:
# 32.0

# %%
sr.median()
# Out:
# 40.0

# %%
sr.std()
# Out:
# 16.431676725154983

# %%
sr.quantile([0.25,0.75])
# Out:
# 0.25    20.0
# 0.75    40.0
# Name: 국어점수, dtype: float64

# %%
# 중복된 값 제거한 후 값의 종류
sr.unique()
# Out:
# array([10, 20, 40, 50], dtype=int64)

# %%
# 값의 갯수
sr.value_counts()
# Out:
# 40    2
# 20    1
# 10    1
# 50    1
# Name: 국어점수, dtype: int64

# %%
def fn(v):
    # print('v =',v)
    # print("==============")

    return v+1 if v >30 else v+2

# %%
sr.apply(fn)
# Out:
# aa    12
# bb    22
# cc    41
# dd    41
# ee    51
# Name: 국어점수, dtype: int64

# %%
sr.apply(lambda v: v+1 if v>30 else v+2)
# Out:
# aa    12
# bb    22
# cc    41
# dd    41
# ee    51
# Name: 국어점수, dtype: int64

# %%
# 국어점수가 40점 이상이면 '합격' 아니면 '불합격'으로 구하시오
sr.apply(lambda v: '합격' if v>=40 else '불합격')
# Out:
# aa    불합격
# bb    불합격
# cc     합격
# dd     합격
# ee     합격
# Name: 국어점수, dtype: object

# %%
# 5개의 범위로 만들어줌
# (9.96, 18.0] : 9.96 < aa <= 18.0
pd.cut(sr,5)
# Out:
# aa    (9.96, 18.0]
# bb    (18.0, 26.0]
# cc    (34.0, 42.0]
# dd    (34.0, 42.0]
# ee    (42.0, 50.0]
# Name: 국어점수, dtype: category
# Categories (5, interval[float64]): [(9.96, 18.0] < (18.0, 26.0] < (26.0, 34.0] < (34.0, 42.0] < (42.0, 50.0]]

# %%
pd.cut(sr,5).value_counts().sort_index()
# Out:
# (9.96, 18.0]    1
# (18.0, 26.0]    1
# (26.0, 34.0]    1
# (34.0, 42.0]    1
# (42.0, 50.0]    1
# Name: 국어점수, dtype: int64

# %%
pd.cut(sr,[0,20,40,60], labels=['20점','40점','60점'])
# Out:
# aa    20점
# bb    20점
# cc    40점
# dd    40점
# ee    60점
# Name: 국어점수, dtype: category
# Categories (3, object): ['20점' < '40점' < '60점']

# %%
sr.to_csv('a.csv')

# %%
for n in sr:
    print(n)
# Out:
# 10
# 20
# 40
# 40
# 50

# %%
for n in sr.index:
    print(n)
# Out:
# aa
# bb
# cc
# dd
# ee

# %%
for i,v in sr.items():
    print(i,v)
# Out:
# aa 10
# bb 20
# cc 40
# dd 40
# ee 50

# %% [markdown]
# ### 시각화

# %%
sr.plot()
plt.show()

# %%
# rot x축 글자 각도
sr.plot(kind='bar', figsize=(8,6), title='성적데이터', legend = True, grid = True, ylim=(0,100),rot=0)
plt.show()

# %%
sr.plot(kind='barh')
plt.show()

# %%
# bins는 cut과 같은 기능으로 계급범위에 맞는 갯수 표현
sr.plot(kind='hist', bins=[0,20,40,60])
plt.show()

# %%
sr.hist(bins=[0,20,40,60])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 전체합에서의 비율
# autopct='%.2f' 비율값 표시
# explode = 간격 띄우기
sr.plot(kind='pie', autopct='%.2f',shadow=False,explode=[0.1,0,0,0])
plt.show()

# %%
sr.quantile()

# %%
sr.plot(kind='box')
plt.show()
